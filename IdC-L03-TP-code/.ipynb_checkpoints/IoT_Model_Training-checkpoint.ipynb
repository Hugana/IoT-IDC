# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as pl

from sklearn.model_selection import cross_validate # for cross validation
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

# %%
# Leitura dos dados
df = pd.read_csv('trainning.data', delimiter=';')
data = np.array(df.values[: , 2:], dtype = float) 
(N, d) = data.shape
print(N, 'x', d)
# Out:
# 120618 x 7

# %%
print(len(df.keys()))
# Out:
# 9
# Index(['date', 'time', 'activity', 'acceleration_x', 'acceleration_y',
#        'acceleration_z', 'gyro_x', 'gyro_y', 'gyro_z'],
#       dtype='object')

# %%
inputs = data[:, 1:] # Neste caso todas as linhas desde a segunda coluna até à última
output = data[:, 0]

# %%
inputs_train, inputs_test, output_train, output_test = train_test_split(inputs,output,test_size = 0.3,shuffle = True)

single_input_test = inputs_test[0]

# %%
SVM = SVC(C = 1.0, kernel = 'linear')
SVM.fit(inputs_train, output_train)
# Out:
# SVC(kernel='linear')

# %%
print('Accuracy:', SVM.score(inputs_test, output_test))
# Out:
# Accuracy: 0.8792903332780634

# %%
print(single_input_test)
print(single_input_test.shape)
# Out:
# [[-0.4328]
#  [-1.2097]
#  [-0.1494]
#  [-0.8171]
#  [ 0.6513]
#  [ 1.9255]]
# (6, 1)

# %%
output_predicted = SVM.predict(single_input_test)
print(output_predicted)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 output_predicted = SVM.predict(single_input_test)
#       2 print(output_predicted)
#
# File ~/Documents/jupyter-workspace/AAA/lib/python3.12/site-packages/sklearn/svm/_base.py:813, in BaseSVC.predict(self, X)
#     811     y = np.argmax(self.decision_function(X), axis=1)
#     812 else:
# --> 813     y = super().predict(X)
#     814 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~/Documents/jupyter-workspace/AAA/lib/python3.12/site-packages/sklearn/svm/_base.py:428, in BaseLibSVM.predict(self, X)
#     412 def predict(self, X):
#     413     """Perform regression on samples in X.
#     414
#     415     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     426         The predicted values.
#     427     """
# --> 428     X = self._validate_for_predict(X)
#     429     predict = self._sparse_predict if self._sparse else self._dense_predict
#     430     return predict(X)
#
# File ~/Documents/jupyter-workspace/AAA/lib/python3.12/site-packages/sklearn/svm/_base.py:606, in BaseLibSVM._validate_for_predict(self, X)
#     603 check_is_fitted(self)
#     605 if not callable(self.kernel):
# --> 606     X = self._validate_data(
#     607         X,
#     608         accept_sparse="csr",
#     609         dtype=np.float64,
#     610         order="C",
#     611         accept_large_sparse=False,
#     612         reset=False,
#     613     )
#     615 if self._sparse and not sp.issparse(X):
#     616     X = sp.csr_matrix(X)
#
# File ~/Documents/jupyter-workspace/AAA/lib/python3.12/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~/Documents/jupyter-workspace/AAA/lib/python3.12/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 1 features, but SVC is expecting 6 features as input.
